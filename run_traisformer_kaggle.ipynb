# %% [markdown]
# # TrAISformer Interpolation Training on Kaggle
#
# This notebook runs TrAISformer interpolation training using the uploaded dataset at `/kaggle/input/datasets/mohammedabdullahai/aisformer/data/ct_dma`.
#
# Trial parameters used from `all_trials.json` index 3 (lr=0.001, bs=32, warmup_tokens=5000, optimizer=adam).

# %%
# 1. Copy repository files from input dataset to /kaggle/working
# !cp -r /kaggle/input/datasets/mohammedabdullahai/aisformer/* /kaggle/working/ || true
# %cd /kaggle/working
# !ls -la | head -n 30

# %%
from pathlib import Path
p = Path('src_interpolation/config_trAISformer.py')
p.write_text(p.read_text().replace('num_workers = 4', 'num_workers = 0'))
print('num_workers set to 0')

# %%
# 2. Install dependencies
# !pip install -r requirements.txt || pip install torch numpy tqdm matplotlib
